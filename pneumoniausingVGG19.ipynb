# %%
# install the dependencies
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)

# %%
from google.colab import files
files.upload() # load kaggle.json file from your computer
# Out:
#      <input type="file" id="files-88dd3f23-a936-483c-9766-9c13c61d6a56" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88dd3f23-a936-483c-9766-9c13c61d6a56">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"balnyaupane","key":"71e9f0cd682737702ecf3ca744f61455"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

#Change the permission
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d balnyaupane/pneumonia-chest-xray-small-dataset -p /content
# Out:
# Downloading pneumonia-chest-xray-small-dataset.zip to /content
#  93% 170M/183M [00:01<00:00, 135MB/s]
# 100% 183M/183M [00:01<00:00, 150MB/s]

# %%
# !unzip -uq "/content/pneumonia-chest-xray-small-dataset.zip" -d "/content/Dataset"

# %%
from keras.applications.vgg19 import VGG19
from keras.models import Model
from keras.layers import Dense,Dropout,Input
from keras.layers import Flatten
from keras_preprocessing.image import ImageDataGenerator
from keras import regularizers
from keras.layers import Activation
from keras.layers import BatchNormalization,Concatenate
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import numpy as np
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# %%
# image size
img_size= 512
img_input = Input(shape=(img_size, img_size, 1))
img_concate = Concatenate()([img_input, img_input, img_input])  

# loading VGG19 model
# include_top: whether to include the fully-connected layers at the top of the network.
model=VGG19(weights='imagenet', include_top=False, input_tensor=img_concate)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step

# %%
# Layers in VGG19 midel
for (i,layer) in enumerate(model.layers):
    print(str(i)+ " "+layer.__class__.__name__,layer.trainable)
    
# layers are by default trainable, so make it non trainable.
for layer in model.layers:
    layer.trainable=False
print("======================================================")   
# lets check the layer become trainable=Fale or Not.
for (i,layer) in enumerate(model.layers):
    print(str(i)+ " "+layer.__class__.__name__,layer.trainable)
# Out:
# 0 InputLayer True
# 1 Concatenate True
# 2 Conv2D True
# 3 Conv2D True
# 4 MaxPooling2D True
# 5 Conv2D True
# 6 Conv2D True
# 7 MaxPooling2D True
# 8 Conv2D True
# 9 Conv2D True
# 10 Conv2D True
# 11 Conv2D True
# 12 MaxPooling2D True
# 13 Conv2D True
# 14 Conv2D True
# 15 Conv2D True
# 16 Conv2D True
# 17 MaxPooling2D True
# 18 Conv2D True
# 19 Conv2D True
# 20 Conv2D True
# 21 Conv2D True
# 22 MaxPooling2D True
# ======================================================
# 0 InputLayer False
# 1 Concatenate False
# 2 Conv2D False
# 3 Conv2D False
# 4 MaxPooling2D False
# 5 Conv2D False
# 6 Conv2D False
# 7 MaxPooling2D False
# 8 Conv2D False
# 9 Conv2D False
# 10 Conv2D False
# 11 Conv2D False
# 12 MaxPooling2D False
# 13 Conv2D False
# 14 Conv2D False
# 15 Conv2D False
# 16 Conv2D False
# 17 MaxPooling2D False
# 18 Conv2D False
# 19 Conv2D False
# 20 Conv2D False
# 21 Conv2D False
# 22 MaxPooling2D False

# %%
#from keras.utils.vis_utils import plot_model
#plot_model(model, to_file='VGG19.png')

# %%
# Now adding fully connected Layer on the ResNet101
flatLayer=model.output
fullConnected=Flatten()(flatLayer)

fullConnected=Dense(128,kernel_regularizer=regularizers.l1_l2(l1=1e-3, l2=1e-4))(fullConnected)
fullConnected=BatchNormalization()(fullConnected)
fullConnected=Activation(activation='relu')(fullConnected)
fullConnected=Dropout(0.5)(fullConnected)

fullConnected=Dense(64,kernel_regularizer=regularizers.l1_l2(l1=1e-3, l2=1e-4))(fullConnected)
fullConnected=BatchNormalization()(fullConnected)
fullConnected=Activation(activation='relu')(fullConnected)
fullConnected=Dropout(0.5)(fullConnected)

fullConnected=Dense(32,kernel_regularizer=regularizers.l1_l2(l1=1e-3, l2=1e-4))(fullConnected)
fullConnected=BatchNormalization()(fullConnected)
fullConnected=Activation(activation='relu')(fullConnected)


output=Dense(1, activation='sigmoid')(fullConnected)
print("model.input:  ",model.input)
# define new model
model = Model(inputs=model.inputs, outputs=output)
# Model summarary
model.summary()
# Out:
# model.input:   KerasTensor(type_spec=TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 512, 512, 3)  0           input_1[0][0]
#                                                                  input_1[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 512, 512, 64) 1792        concatenate[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 512, 512, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 256, 256, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 256, 256, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 256, 256, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 128, 128, 128 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 128, 128, 256 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 128, 128, 256 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 128, 128, 256 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv4 (Conv2D)           (None, 128, 128, 256 590080      block3_conv3[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 64, 64, 256)  0           block3_conv4[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 64, 64, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 64, 64, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 64, 64, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_conv4 (Conv2D)           (None, 64, 64, 512)  2359808     block4_conv3[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 32, 32, 512)  0           block4_conv4[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 32, 32, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 32, 32, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 32, 32, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_conv4 (Conv2D)           (None, 32, 32, 512)  2359808     block5_conv3[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 16, 16, 512)  0           block5_conv4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 131072)       0           block5_pool[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          16777344    flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128)          512         dense[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128)          0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           activation[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64)           256         dense_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64)           0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           activation_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           2080        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32)           128         dense_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            33          activation_2[0][0]
# ==================================================================================================
# Total params: 36,812,993
# Trainable params: 16,788,161
# Non-trainable params: 20,024,832
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
opt = Adam(learning_rate=0.0000015,beta_1=0.899,beta_2=0.999,epsilon=1e-06)

#compiling the cnn
model.compile(optimizer=opt , loss='binary_crossentropy',metrics=['accuracy'])

#part2- fitting the CNN to the images
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator()

test_datagen = ImageDataGenerator()

training_set = train_datagen.flow_from_directory('/content/Dataset/Pneumonia_Chest _X-ray_Small_Dataset/Trainingdata',
        target_size=(512, 512),
        batch_size=52,
        color_mode='grayscale',
        class_mode='binary')

print("training_set.class_indices: ",training_set.class_indices)

test_set = test_datagen.flow_from_directory('/content/Dataset/Pneumonia_Chest _X-ray_Small_Dataset/Testdata',
        target_size=(512,512),
        batch_size=26,
        color_mode='grayscale',
        shuffle=False,
        class_mode='binary')

print("training_set.class_indices: ",training_set.class_indices)
print("test_set.class_indices: ",test_set.class_indices)
print(" print(len(training_set)):  ",len(training_set))
print(" print(len(test_set)):  ",len(test_set))
# Out:
# Found 2105 images belonging to 2 classes.
# training_set.class_indices:  {'Normal': 0, 'Pneumonia': 1}
# Found 480 images belonging to 2 classes.
# training_set.class_indices:  {'Normal': 0, 'Pneumonia': 1}
# test_set.class_indices:  {'Normal': 0, 'Pneumonia': 1}
#  print(len(training_set)):   41
#  print(len(test_set)):   19

# %%
# simple early stopping
my_callbacks = [EarlyStopping(monitor='val_loss', mode='min', patience=5,verbose=1)]

# %%
History = model.fit(training_set, 
                    validation_data= test_set, 
                    steps_per_epoch=len(training_set),
                    epochs=100,
                    validation_steps=len(test_set),
                    verbose=1,
                    callbacks=my_callbacks
                 )
# Out:
# Epoch 1/100
# 41/41 [==============================] - 305s 5s/step - loss: 58.1552 - accuracy: 0.5525 - val_loss: 57.7575 - val_accuracy: 0.6062
# Epoch 2/100
# 41/41 [==============================] - 129s 3s/step - loss: 57.4909 - accuracy: 0.6271 - val_loss: 57.1019 - val_accuracy: 0.7042
# Epoch 3/100
# 41/41 [==============================] - 129s 3s/step - loss: 56.8601 - accuracy: 0.6926 - val_loss: 56.4908 - val_accuracy: 0.7646
# Epoch 4/100
# 41/41 [==============================] - 129s 3s/step - loss: 56.2479 - accuracy: 0.7268 - val_loss: 55.8890 - val_accuracy: 0.8250
# 41/41 [==============================] - 129s 3s/step - loss: 16.6818 - accuracy: 0.9449 - val_loss: 16.5330 - val_accuracy: 0.9375
# Epoch 86/100
# 41/41 [==============================] - 129s 3s/step - loss: 16.3673 - accuracy: 0.9587 - val_loss: 16.2283 - val_accuracy: 0.9375
# Epoch 87/100
# 41/41 [==============================] - 129s 3s/step - loss: 16.0726 - accuracy: 0.9515 - val_loss: 15.9304 - val_accuracy: 0.9375
# Epoch 88/100
# 41/41 [==============================] - 129s 3s/step - loss: 15.7766 - accuracy: 0.9411 - val_loss: 15.6379 - val_accuracy: 0.9354
# Epoch 89/100
# 41/41 [==============================] - 129s 3s/step - loss: 15.4854 - accuracy: 0.9506 - val_loss: 15.3510 - val_accuracy: 0.9354
# Epoch 90/100
# 41/41 [==============================] - 129s 3s/step - loss: 15.2045 - accuracy: 0.9506 - val_loss: 15.0703 - val_accuracy: 0.9354
# Epoch 91/100
# 41/41 [==============================] - 129s 3s/step - loss: 14.9158 - accuracy: 0.9591 - val_loss: 14.7940 - val_accuracy: 0.9354
# Epoch 92/100
# 41/41 [==============================] - 129s 3s/step - loss: 14.6469 - accuracy: 0.9563 - val_loss: 14.5218 - val_accuracy: 0.9354
# Epoch 93/100
# 41/41 [==============================] - 129s 3s/step - loss: 14.3800 - accuracy: 0.9530 - val_loss: 14.2590 - val_accuracy: 0.9354
# Epoch 94/100
# 41/41 [==============================] - 129s 3s/step - loss: 14.1168 - accuracy: 0.9568 - val_loss: 13.9974 - val_accuracy: 0.9354
# Epoch 95/100
# 41/41 [==============================] - 129s 3s/step - loss: 13.8590 - accuracy: 0.9549 - val_loss: 13.7430 - val_accuracy: 0.9354
# Epoch 96/100
# 41/41 [==============================] - 129s 3s/step - loss: 13.6052 - accuracy: 0.9568 - val_loss: 13.4943 - val_accuracy: 0.9333
# Epoch 97/100
# 41/41 [==============================] - 129s 3s/step - loss: 13.3568 - accuracy: 0.9596 - val_loss: 13.2484 - val_accuracy: 0.9354
# Epoch 98/100
# 41/41 [==============================] - 129s 3s/step - loss: 13.1211 - accuracy: 0.9539 - val_loss: 13.0111 - val_accuracy: 0.9354
# Epoch 99/100
# 41/41 [==============================] - 129s 3s/step - loss: 12.8837 - accuracy: 0.9625 - val_loss: 12.7795 - val_accuracy: 0.9354
# Epoch 100/100
# 41/41 [==============================] - 129s 3s/step - loss: 12.6559 - accuracy: 0.9610 - val_loss: 12.5538 - val_accuracy: 0.9333

# %%
# summarize history for accuracy
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %%
# summarize history for loss
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
## calculate model's accuracy on test set with use of keras .evaluate_generator() function.
scoreTest = model.evaluate(test_set)
print("Test Accuracy: ",scoreTest[1]*100)

scoreTrain = model.evaluate(training_set)
print("Training Accuracy: ",scoreTrain[1]*100)

preds = model.predict(test_set)
y_preds = np.where(preds >=0.5, 1, 0)

cfm = confusion_matrix(test_set.classes, y_preds)
print("============Confusion Matrix=====================",cfm)
print("=========Classification_Report==================",classification_report(test_set.classes, y_preds))
# Out:
# 19/19 [==============================] - 26s 1s/step - loss: 12.5538 - accuracy: 0.9333
# Test Accuracy:  93.33333373069763
# 41/41 [==============================] - 103s 3s/step - loss: 12.4857 - accuracy: 0.9938
# Training Accuracy:  99.38242435455322
# ============Confusion Matrix===================== [[218  17]
#  [ 15 230]]
# =========Classification_Report==================               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       235
#            1       0.93      0.94      0.93       245
#
#     accuracy                           0.93       480
#    macro avg       0.93      0.93      0.93       480
# weighted avg       0.93      0.93      0.93       480

# %%
#test_set.classes

# %%
group_names = ["True Positive","False Negative","False Positive","True Negative"]
group_counts = ['{0:0.0f}'.format(value) for value in cfm.flatten()]

labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names,group_counts)]
labels = np.asarray(labels).reshape(2,2)

plt.figure(figsize=(8,6))
ax= plt.subplot()
sns.heatmap(cfm, annot=labels, fmt='', cmap='Blues', ax = ax)
# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('Actual labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['Normal', 'Pneumonia'])
ax.yaxis.set_ticklabels(['Normal', 'Pneumonia'])
plt.show()

# %%
# image size
img_size= 512
img_input = Input(shape=(img_size, img_size, 1))
img_concate = Concatenate()([img_input, img_input, img_input])  

# loading VGG19 model
# include_top: whether to include the fully-connected layers at the top of the network.
model=VGG19(weights='imagenet', include_top=False, input_tensor=img_concate)

# making all layer trainable
for layer in model.layers:
    layer.trainable = True

# Fine-tune from this layer onwards
fine_tune_at = 13
# Freeze all the layers before the `fine_tune_at` layer
for layer in model.layers[:fine_tune_at]:
  layer.trainable =  False

# lets check the layer become trainable=Fale or Not.
for (i,layer) in enumerate(model.layers):
    print(str(i)+ " "+layer.__class__.__name__,layer.trainable)


# Now adding fully connected Layer on the ResNet101
flatLayer=model.output
fullConnected=Flatten()(flatLayer)

fullConnected=Dense(128,kernel_regularizer=regularizers.l1_l2(l1=1e-3, l2=1e-4))(fullConnected)
fullConnected=BatchNormalization()(fullConnected)
fullConnected=Activation(activation='relu')(fullConnected)
fullConnected=Dropout(0.5)(fullConnected)

fullConnected=Dense(64,kernel_regularizer=regularizers.l1_l2(l1=1e-3, l2=1e-4))(fullConnected)
fullConnected=BatchNormalization()(fullConnected)
fullConnected=Activation(activation='relu')(fullConnected)
fullConnected=Dropout(0.5)(fullConnected)

fullConnected=Dense(32,kernel_regularizer=regularizers.l1_l2(l1=1e-3, l2=1e-4))(fullConnected)
fullConnected=BatchNormalization()(fullConnected)
fullConnected=Activation(activation='relu')(fullConnected)


output=Dense(1, activation='sigmoid')(fullConnected)
print("model.input:  ",model.input)
# define new model
model = Model(inputs=model.inputs, outputs=output)
# Model summarary
model.summary()


from tensorflow.keras.optimizers import Adam
opt = Adam(learning_rate=0.0000015,beta_1=0.899,beta_2=0.999,epsilon=1e-07)

#compiling the cnn
model.compile(optimizer=opt , loss='binary_crossentropy',metrics=['accuracy'])

#part2- fitting the CNN to the images
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator()

test_datagen = ImageDataGenerator()

training_set = train_datagen.flow_from_directory('/content/Dataset/Pneumonia_Chest _X-ray_Small_Dataset/Trainingdata',
        target_size=(512, 512),
        batch_size=32,
        color_mode='grayscale',
        class_mode='binary')

test_set = test_datagen.flow_from_directory('/content/Dataset/Pneumonia_Chest _X-ray_Small_Dataset/Testdata',
        target_size=(512,512),
        batch_size=16,
        color_mode='grayscale',
        shuffle=False,
        class_mode='binary')

print("test_set.class_indices: ",test_set.class_indices)
print("training_set.class_indices: ",training_set.class_indices)

# simple early stopping
my_callbacks = [EarlyStopping(monitor='val_loss', mode='min', patience=5,verbose=1)]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step
# 0 InputLayer False
# 1 Concatenate False
# 2 Conv2D False
# 3 Conv2D False
# 4 MaxPooling2D False
# 5 Conv2D False
# 6 Conv2D False
# 7 MaxPooling2D False
# 8 Conv2D False
# 9 Conv2D False
# 10 Conv2D False
# 11 Conv2D False
# 12 MaxPooling2D False
# 13 Conv2D True
# 14 Conv2D True
# 15 Conv2D True
# 16 Conv2D True
# 17 MaxPooling2D True
# 18 Conv2D True
# 19 Conv2D True
# 20 Conv2D True
# 21 Conv2D True
# 22 MaxPooling2D True
# model.input:   KerasTensor(type_spec=TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 512, 512, 3)  0           input_1[0][0]
#                                                                  input_1[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 512, 512, 64) 1792        concatenate[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 512, 512, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 256, 256, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 256, 256, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 256, 256, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 128, 128, 128 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 128, 128, 256 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 128, 128, 256 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 128, 128, 256 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv4 (Conv2D)           (None, 128, 128, 256 590080      block3_conv3[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 64, 64, 256)  0           block3_conv4[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 64, 64, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 64, 64, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 64, 64, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_conv4 (Conv2D)           (None, 64, 64, 512)  2359808     block4_conv3[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 32, 32, 512)  0           block4_conv4[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 32, 32, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 32, 32, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 32, 32, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_conv4 (Conv2D)           (None, 32, 32, 512)  2359808     block5_conv3[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 16, 16, 512)  0           block5_conv4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 131072)       0           block5_pool[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          16777344    flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128)          512         dense[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128)          0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           activation[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64)           256         dense_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64)           0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           activation_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           2080        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32)           128         dense_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            33          activation_2[0][0]
# ==================================================================================================
# Total params: 36,812,993
# Trainable params: 34,486,977
# Non-trainable params: 2,326,016
# __________________________________________________________________________________________________
# Found 2105 images belonging to 2 classes.
# Found 480 images belonging to 2 classes.
# test_set.class_indices:  {'Normal': 0, 'Pneumonia': 1}
# training_set.class_indices:  {'Normal': 0, 'Pneumonia': 1}

# %%
History = model.fit(training_set, 
                    validation_data= test_set, 
                    steps_per_epoch=len(training_set),
                    epochs=100,
                    validation_steps=len(test_set),
                    verbose=1,
                    callbacks=my_callbacks
                 )
# Out:
# Epoch 1/100
# 66/66 [==============================] - 308s 4s/step - loss: 57.9725 - accuracy: 0.5981 - val_loss: 57.3441 - val_accuracy: 0.8417
# Epoch 2/100
# 66/66 [==============================] - 179s 3s/step - loss: 57.0109 - accuracy: 0.7311 - val_loss: 56.4538 - val_accuracy: 0.8729
# Epoch 3/100
# 66/66 [==============================] - 179s 3s/step - loss: 56.1065 - accuracy: 0.7848 - val_loss: 55.5818 - val_accuracy: 0.8854
# Epoch 4/100
# 66/66 [==============================] - 179s 3s/step - loss: 55.2085 - accuracy: 0.8257 - val_loss: 54.7131 - val_accuracy: 0.8917
# Epoch 5/100
# 66/66 [==============================] - 179s 3s/step - loss: 54.3207 - accuracy: 0.8580 - val_loss: 53.8403 - val_accuracy: 0.9062
# Epoch 6/100
# 66/66 [==============================] - 179s 3s/step - loss: 53.4340 - accuracy: 0.8660 - val_loss: 52.9605 - val_accuracy: 0.9021
# Epoch 7/100
# 66/66 [==============================] - 179s 3s/step - loss: 52.5528 - accuracy: 0.8656 - val_loss: 52.0785 - val_accuracy: 0.9208
# Epoch 8/100
# 66/66 [==============================] - 179s 3s/step - loss: 51.6637 - accuracy: 0.8803 - val_loss: 51.1930 - val_accuracy: 0.9125
# Epoch 9/100
# 66/66 [==============================] - 179s 3s/step - loss: 50.7771 - accuracy: 0.8974 - val_loss: 50.3029 - val_accuracy: 0.9146
# 66/66 [==============================] - 179s 3s/step - loss: 5.9432 - accuracy: 0.9914 - val_loss: 5.9499 - val_accuracy: 0.9208
# Epoch 91/100
# 66/66 [==============================] - 179s 3s/step - loss: 5.7943 - accuracy: 0.9929 - val_loss: 5.7814 - val_accuracy: 0.9354
# Epoch 92/100
# 66/66 [==============================] - 179s 3s/step - loss: 5.6600 - accuracy: 0.9924 - val_loss: 5.6467 - val_accuracy: 0.9292
# Epoch 93/100
# 66/66 [==============================] - 179s 3s/step - loss: 5.5252 - accuracy: 0.9914 - val_loss: 5.4988 - val_accuracy: 0.9333
# Epoch 94/100
# 66/66 [==============================] - 179s 3s/step - loss: 5.3939 - accuracy: 0.9929 - val_loss: 5.3812 - val_accuracy: 0.9271
# Epoch 95/100
# 66/66 [==============================] - 179s 3s/step - loss: 5.2656 - accuracy: 0.9957 - val_loss: 5.2664 - val_accuracy: 0.9292
# Epoch 96/100
# 66/66 [==============================] - 179s 3s/step - loss: 5.1441 - accuracy: 0.9938 - val_loss: 5.1372 - val_accuracy: 0.9292
# Epoch 97/100
# 66/66 [==============================] - 179s 3s/step - loss: 5.0254 - accuracy: 0.9938 - val_loss: 5.0228 - val_accuracy: 0.9292
# Epoch 98/100
# 66/66 [==============================] - 179s 3s/step - loss: 4.9126 - accuracy: 0.9933 - val_loss: 4.9256 - val_accuracy: 0.9250
# Epoch 99/100
# 66/66 [==============================] - 179s 3s/step - loss: 4.7955 - accuracy: 0.9943 - val_loss: 4.8165 - val_accuracy: 0.9229
# Epoch 100/100
# 66/66 [==============================] - 179s 3s/step - loss: 4.6919 - accuracy: 0.9967 - val_loss: 4.6929 - val_accuracy: 0.9333

# %%
# summarize history for accuracy
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %%
# summarize history for loss
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# calculate model's accuracy on test set with use of keras .evaluate_generator() function.
score = model.evaluate(test_set)
print("Test Accuracy: ",score[1]*100)

preds = model.predict(test_set)
y_preds = np.where(preds >=0.5, 1, 0)

cfm = confusion_matrix(test_set.classes, y_preds)

print("============Confusion Matrix=====================\n",cfm)
print("=========Classification_Report==================\n",classification_report(test_set.classes, y_preds))
# Out:
# 30/30 [==============================] - 25s 833ms/step - loss: 4.6929 - accuracy: 0.9333
# Test Accuracy:  93.33333373069763
# ============Confusion Matrix=====================
#  [[209  26]
#  [  6 239]]
# =========Classification_Report==================
#                precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93       235
#            1       0.90      0.98      0.94       245
#
#     accuracy                           0.93       480
#    macro avg       0.94      0.93      0.93       480
# weighted avg       0.94      0.93      0.93       480

# %%
group_names = ["True Positive","False Negative","False Positive","True Negative"]
group_counts = ['{0:0.0f}'.format(value) for value in cfm.flatten()]

labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names,group_counts)]
labels = np.asarray(labels).reshape(2,2)

plt.figure(figsize=(8,6))
ax= plt.subplot()
sns.heatmap(cfm, annot=labels, fmt='', cmap='Blues', ax = ax)
# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('Actual labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['Normal', 'Pneumonia'])
ax.yaxis.set_ticklabels(['Normal', 'Pneumonia'])
plt.show()

# %%
# image size
img_size= 512
img_input = Input(shape=(img_size, img_size, 1))
img_concate = Concatenate()([img_input, img_input, img_input])  

# loading VGG19 model
# include_top: whether to include the fully-connected layers at the top of the network.
model=VGG19(weights='imagenet', include_top=False, input_tensor=img_concate)

# making all layer trainable
for layer in model.layers:
    layer.trainable = True

# lets check the layer become trainable=Fale or Not.
for (i,layer) in enumerate(model.layers):
    print(str(i)+ " "+layer.__class__.__name__,layer.trainable)


# Now adding fully connected Layer on the ResNet101
flatLayer=model.output
fullConnected=Flatten()(flatLayer)

fullConnected=Dense(4,kernel_regularizer=regularizers.l1_l2(l1=1e-3, l2=1e-4))(fullConnected)
fullConnected=BatchNormalization()(fullConnected)
fullConnected=Activation(activation='relu')(fullConnected)


output=Dense(1, activation='sigmoid')(fullConnected)
print("model.input:  ",model.input)
# define new model
model = Model(inputs=model.inputs, outputs=output)
# Model summarary
model.summary()


from tensorflow.keras.optimizers import Adam
opt = Adam(learning_rate=0.0000015,beta_1=0.899,beta_2=0.999,epsilon=1e-07)

#compiling the cnn
model.compile(optimizer=opt , loss='binary_crossentropy',metrics=['accuracy'])

#part2- fitting the CNN to the images
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator()

test_datagen = ImageDataGenerator()

training_set = train_datagen.flow_from_directory('/content/Dataset/Pneumonia_Chest _X-ray_Small_Dataset/Trainingdata',
        target_size=(512, 512),
        batch_size=16,
        color_mode='grayscale',
        class_mode='binary')

test_set = test_datagen.flow_from_directory('/content/Dataset/Pneumonia_Chest _X-ray_Small_Dataset/Testdata',
        target_size=(512,512),
        batch_size=8,
        color_mode='grayscale',
        shuffle=False,
        class_mode='binary')

print("test_set.class_indices: ",test_set.class_indices)
print("training_set.class_indices: ",training_set.class_indices)

# simple early stopping
my_callbacks = [EarlyStopping(monitor='val_loss', mode='min', patience=5,verbose=1)]
# Out:
# 0 InputLayer True
# 1 Concatenate True
# 2 Conv2D True
# 3 Conv2D True
# 4 MaxPooling2D True
# 5 Conv2D True
# 6 Conv2D True
# 7 MaxPooling2D True
# 8 Conv2D True
# 9 Conv2D True
# 10 Conv2D True
# 11 Conv2D True
# 12 MaxPooling2D True
# 13 Conv2D True
# 14 Conv2D True
# 15 Conv2D True
# 16 Conv2D True
# 17 MaxPooling2D True
# 18 Conv2D True
# 19 Conv2D True
# 20 Conv2D True
# 21 Conv2D True
# 22 MaxPooling2D True
# model.input:   KerasTensor(type_spec=TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32, name='input_3'), name='input_3', description="created by layer 'input_3'")
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 512, 512, 3)  0           input_3[0][0]
#                                                                  input_3[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 512, 512, 64) 1792        concatenate_2[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 512, 512, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 256, 256, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 256, 256, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 256, 256, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 128, 128, 128 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 128, 128, 256 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 128, 128, 256 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 128, 128, 256 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv4 (Conv2D)           (None, 128, 128, 256 590080      block3_conv3[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 64, 64, 256)  0           block3_conv4[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 64, 64, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 64, 64, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 64, 64, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_conv4 (Conv2D)           (None, 64, 64, 512)  2359808     block4_conv3[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 32, 32, 512)  0           block4_conv4[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 32, 32, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 32, 32, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 32, 32, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_conv4 (Conv2D)           (None, 32, 32, 512)  2359808     block5_conv3[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 16, 16, 512)  0           block5_conv4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 131072)       0           block5_pool[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            524292      flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 4)            16          dense_5[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 4)            0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            5           activation_3[0][0]
# ==================================================================================================
# Total params: 20,548,697
# Trainable params: 20,548,689
# Non-trainable params: 8
# __________________________________________________________________________________________________
# Found 2105 images belonging to 2 classes.
# Found 480 images belonging to 2 classes.
# test_set.class_indices:  {'Normal': 0, 'Pneumonia': 1}
# training_set.class_indices:  {'Normal': 0, 'Pneumonia': 1}

# %%
History = model.fit(training_set, 
                    validation_data= test_set, 
                    steps_per_epoch=len(training_set),
                    epochs=50,
                    validation_steps=len(test_set),
                    verbose=1,
                    callbacks=my_callbacks
                 )
# Out:
# Epoch 1/50
# 132/132 [==============================] - 376s 3s/step - loss: 2.0789 - accuracy: 0.9663 - val_loss: 2.0688 - val_accuracy: 0.9125
# Epoch 2/50
# 132/132 [==============================] - 376s 3s/step - loss: 2.0311 - accuracy: 0.9715 - val_loss: 2.0290 - val_accuracy: 0.9229
# Epoch 3/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.9811 - accuracy: 0.9772 - val_loss: 1.9787 - val_accuracy: 0.9312
# Epoch 4/50
# 132/132 [==============================] - 375s 3s/step - loss: 1.9315 - accuracy: 0.9810 - val_loss: 1.9316 - val_accuracy: 0.9250
# Epoch 5/50
# 132/132 [==============================] - 375s 3s/step - loss: 1.8774 - accuracy: 0.9872 - val_loss: 1.8905 - val_accuracy: 0.9250
# Epoch 6/50
# 132/132 [==============================] - 375s 3s/step - loss: 1.8302 - accuracy: 0.9881 - val_loss: 1.8365 - val_accuracy: 0.9312
# Epoch 7/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.7844 - accuracy: 0.9914 - val_loss: 1.7863 - val_accuracy: 0.9292
# Epoch 8/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.7345 - accuracy: 0.9895 - val_loss: 1.7477 - val_accuracy: 0.9292
# Epoch 9/50
# 132/132 [==============================] - 377s 3s/step - loss: 1.6864 - accuracy: 0.9967 - val_loss: 1.6927 - val_accuracy: 0.9292
# Epoch 10/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.6343 - accuracy: 0.9981 - val_loss: 1.6487 - val_accuracy: 0.9312
# Epoch 11/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.5888 - accuracy: 0.9967 - val_loss: 1.6017 - val_accuracy: 0.9354
# Epoch 12/50
# 132/132 [==============================] - 377s 3s/step - loss: 1.5386 - accuracy: 0.9990 - val_loss: 1.5564 - val_accuracy: 0.9354
# Epoch 13/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.4940 - accuracy: 0.9971 - val_loss: 1.5072 - val_accuracy: 0.9292
# Epoch 14/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.4486 - accuracy: 0.9986 - val_loss: 1.4634 - val_accuracy: 0.9312
# Epoch 15/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.4032 - accuracy: 0.9981 - val_loss: 1.4180 - val_accuracy: 0.9312
# Epoch 16/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.3572 - accuracy: 0.9986 - val_loss: 1.3742 - val_accuracy: 0.9333
# Epoch 17/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.3143 - accuracy: 0.9995 - val_loss: 1.3272 - val_accuracy: 0.9312
# Epoch 18/50
# 132/132 [==============================] - 377s 3s/step - loss: 1.2684 - accuracy: 0.9990 - val_loss: 1.2888 - val_accuracy: 0.9333
# Epoch 19/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.2271 - accuracy: 0.9986 - val_loss: 1.2455 - val_accuracy: 0.9312
# Epoch 20/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.1840 - accuracy: 0.9995 - val_loss: 1.2040 - val_accuracy: 0.9354
# Epoch 21/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.1445 - accuracy: 0.9995 - val_loss: 1.1707 - val_accuracy: 0.9312
# Epoch 22/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.1052 - accuracy: 0.9995 - val_loss: 1.1297 - val_accuracy: 0.9312
# Epoch 23/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.0668 - accuracy: 0.9995 - val_loss: 1.0924 - val_accuracy: 0.9271
# Epoch 24/50
# 132/132 [==============================] - 376s 3s/step - loss: 1.0303 - accuracy: 0.9995 - val_loss: 1.0589 - val_accuracy: 0.9292
# Epoch 25/50
# 132/132 [==============================] - 376s 3s/step - loss: 0.9984 - accuracy: 0.9995 - val_loss: 1.0232 - val_accuracy: 0.9312
# Epoch 26/50
# 132/132 [==============================] - 376s 3s/step - loss: 0.9629 - accuracy: 0.9995 - val_loss: 0.9880 - val_accuracy: 0.9271
# Epoch 27/50
# 132/132 [==============================] - 376s 3s/step - loss: 0.9300 - accuracy: 0.9995 - val_loss: 0.9567 - val_accuracy: 0.9312
# Epoch 28/50
# 132/132 [==============================] - 376s 3s/step - loss: 0.9059 - accuracy: 0.9952 - val_loss: 0.9240 - val_accuracy: 0.9229
# Epoch 29/50
# 132/132 [==============================] - 376s 3s/step - loss: 0.8721 - accuracy: 0.9981 - val_loss: 0.8965 - val_accuracy: 0.9354
# Epoch 30/50
# 132/132 [==============================] - 376s 3s/step - loss: 0.8436 - accuracy: 0.9986 - val_loss: 0.8686 - val_accuracy: 0.9375
# Epoch 31/50
# 132/132 [==============================] - 378s 3s/step - loss: 0.8164 - accuracy: 0.9995 - val_loss: 0.8498 - val_accuracy: 0.9333
# Epoch 32/50
# 132/132 [==============================] - 378s 3s/step - loss: 0.7929 - accuracy: 0.9995 - val_loss: 0.8326 - val_accuracy: 0.9292
# Epoch 33/50
# 132/132 [==============================] - 379s 3s/step - loss: 0.7710 - accuracy: 0.9995 - val_loss: 0.8106 - val_accuracy: 0.9312
# Epoch 34/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.7502 - accuracy: 0.9995 - val_loss: 0.7804 - val_accuracy: 0.9333
# Epoch 35/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.7303 - accuracy: 0.9995 - val_loss: 0.7675 - val_accuracy: 0.9333
# Epoch 36/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.7142 - accuracy: 0.9995 - val_loss: 0.7451 - val_accuracy: 0.9354
# Epoch 37/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.6952 - accuracy: 0.9995 - val_loss: 0.7298 - val_accuracy: 0.9354
# Epoch 38/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.6780 - accuracy: 0.9995 - val_loss: 0.7148 - val_accuracy: 0.9375
# Epoch 39/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.6604 - accuracy: 0.9995 - val_loss: 0.7021 - val_accuracy: 0.9312
# Epoch 40/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.6459 - accuracy: 0.9995 - val_loss: 0.6864 - val_accuracy: 0.9354
# Epoch 41/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.6323 - accuracy: 0.9995 - val_loss: 0.6719 - val_accuracy: 0.9312
# Epoch 42/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.6163 - accuracy: 0.9995 - val_loss: 0.6556 - val_accuracy: 0.9354
# Epoch 43/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.6088 - accuracy: 0.9967 - val_loss: 0.6346 - val_accuracy: 0.9271
# Epoch 44/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.5970 - accuracy: 0.9971 - val_loss: 0.6264 - val_accuracy: 0.9354
# Epoch 45/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.5850 - accuracy: 0.9986 - val_loss: 0.6212 - val_accuracy: 0.9312
# Epoch 46/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.5763 - accuracy: 0.9995 - val_loss: 0.6172 - val_accuracy: 0.9333
# Epoch 47/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.5689 - accuracy: 0.9986 - val_loss: 0.6046 - val_accuracy: 0.9354
# Epoch 48/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.5580 - accuracy: 0.9990 - val_loss: 0.6034 - val_accuracy: 0.9354
# Epoch 49/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.5514 - accuracy: 0.9995 - val_loss: 0.5934 - val_accuracy: 0.9354
# Epoch 50/50
# 132/132 [==============================] - 380s 3s/step - loss: 0.5427 - accuracy: 0.9995 - val_loss: 0.5887 - val_accuracy: 0.9333

# %%
# summarize history for accuracy
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %%
# summarize history for loss
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# calculate model's accuracy on test set with use of keras .evaluate_generator() function.
score = model.evaluate(test_set)
print("Test Accuracy: ",score[1]*100)

preds = model.predict(test_set)
y_preds = np.where(preds >=0.5, 1, 0)

cfm = confusion_matrix(test_set.classes, y_preds)
print("============Confusion Matrix=====================\n",cfm)
print("=========Classification_Report==================\n",classification_report(test_set.classes, y_preds))
# Out:
# 60/60 [==============================] - 38s 627ms/step - loss: 0.5887 - accuracy: 0.9333
# Test Accuracy:  93.33333373069763
# ============Confusion Matrix=====================
#  [[211  24]
#  [  8 237]]
# =========Classification_Report==================
#                precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93       235
#            1       0.91      0.97      0.94       245
#
#     accuracy                           0.93       480
#    macro avg       0.94      0.93      0.93       480
# weighted avg       0.94      0.93      0.93       480

# %%
group_names = ["True Positive","False Negative","False Positive","True Negative"]
group_counts = ['{0:0.0f}'.format(value) for value in cfm.flatten()]

labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_names,group_counts)]
labels = np.asarray(labels).reshape(2,2)

plt.figure(figsize=(8,6))
ax= plt.subplot()
sns.heatmap(cfm, annot=labels, fmt='', cmap='Blues', ax = ax)
# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('Actual labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['Normal', 'Pneumonia'])
ax.yaxis.set_ticklabels(['Normal', 'Pneumonia'])
plt.show()
